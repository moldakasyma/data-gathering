# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
data = pd.read_csv("/Users/aja/Desktop/uni/datagath/Hot100.csv")

# %%
#understanding data and checking he first 5 rows
data.head()
# Out:
#              Track         Artist                   Album  Year  Duration  \
# 0          7 rings  Ariana Grande           thank u, next  2019    178626
# 1       Break Free  Ariana Grande  My Everything - Deluxe  2014    214840
# 2  Dangerous Woman  Ariana Grande         Dangerous Woman  2016    235946
# 3   God is a woman  Ariana Grande               Sweetener  2018    197546
# 4         Into You  Ariana Grande         Dangerous Woman  2016    244453
#
#    Time_Signature  Danceability  Energy  Key  Loudness  Mode  Speechiness  \
# 0               4         0.780   0.321    1   -10.747     0       0.3720
# 1               4         0.686   0.702    7    -5.325     0       0.0455
# 2               3         0.664   0.602    4    -5.369     0       0.0412
# 3               4         0.602   0.658    1    -5.934     1       0.0558
# 4               4         0.623   0.734    9    -5.948     1       0.1070
#
#    Acousticness  Instrumentalness  Liveness  Valence    Tempo  Popularity
# ...

# %%
#understanding data and checking the last 5 rows
data.tail()
# Out:
#                                              Track      Artist  \
# 615  I Remember Everything (feat. Kacey Musgraves)  Zach Bryan
# 616                          If She Wants a Cowboy  Zach Bryan
# 617                             Letting Someone Go  Zach Bryan
# 618                        Something in the Orange  Zach Bryan
# 619                               Summertime Blues  Zach Bryan
#
#                        Album  Year  Duration  Time_Signature  Danceability  \
# 615               Zach Bryan  2022    227195               4         0.429
# 616      American Heartbreak  2023    192293               4         0.553
# 617                    DeAnn  2022    239761               4         0.543
# 618  Something in the Orange  2022    228013               3         0.369
# 619         Summertime Blues  2022    181239               4         0.552
#
#      Energy  Key  Loudness  Mode  Speechiness  Acousticness  Instrumentalness  \
# ...

# %%
#number of columns and rows
data.shape
# Out:
# (620, 18)

# %%
data.describe()
# Out:
#               Year       Duration  Time_Signature  Danceability      Energy  \
# count   620.000000     620.000000      620.000000    620.000000  620.000000
# mean   2018.838710  203485.632258        3.909677      0.649694    0.642857
# std       4.633563   43636.830312        0.352563      0.139674    0.176589
# min    2001.000000   36226.000000        1.000000      0.261000    0.043600
# 25%    2017.000000  178920.250000        4.000000      0.549000    0.525000
# 50%    2020.000000  201936.500000        4.000000      0.651500    0.658500
# 75%    2022.000000  226866.000000        4.000000      0.752250    0.786250
# max    2023.000000  613026.000000        5.000000      0.968000    0.970000
#
#               Key    Loudness        Mode  Speechiness  Acousticness  \
# count  620.000000  620.000000  620.000000   620.000000    620.000000
# mean     5.516129   -6.249318    0.659677     0.099305      0.238536
# std      3.658888    2.302341    0.474200     0.106227      0.252794
# ...

# %%
#showing names of columns
data.columns
# Out:
# Index(['Track', 'Artist', 'Album', 'Year', 'Duration', 'Time_Signature',
#        'Danceability', 'Energy', 'Key', 'Loudness', 'Mode', 'Speechiness',
#        'Acousticness', 'Instrumentalness', 'Liveness', 'Valence', 'Tempo',
#        'Popularity'],
#       dtype='object')

# %%
#checking uniqueness
data.nunique()
# Out:
# Track               616
# Artist               87
# Album               419
# Year                 23
# Duration            613
# Time_Signature        4
# Danceability        370
# Energy              392
# Key                  12
# Loudness            593
# Mode                  2
# Speechiness         428
# Acousticness        512
# Instrumentalness    293
# Liveness            343
# Valence             438
# Tempo               611
# Popularity           70
# dtype: int64

# %%
#checking uniqueness by certain column
data['Year'].unique()
# Out:
# array([2019, 2014, 2016, 2018, 2020, 2017, 2023, 2022, 2003, 2013, 2008,
#        2006, 2011, 2021, 2005, 2007, 2010, 2015, 2009, 2012, 2004, 2002,
#        2001])

# %%
#cleaning the data

# %%
#checking null values
data.isnull().sum()
# Out:
# Track               0
# Artist              0
# Album               0
# Year                0
# Duration            0
# Time_Signature      0
# Danceability        0
# Energy              0
# Key                 0
# Loudness            0
# Mode                0
# Speechiness         0
# Acousticness        0
# Instrumentalness    0
# Liveness            0
# Valence             0
# Tempo               0
# Popularity          0
# dtype: int64

# %%
#as you can see we have null values, therefor we don't have to remove or replace any columns and rows

# %%
#removing columns that i don't need they are Valence, Instrumentalness, Speechiness,mode
hot100=data.drop(['Valence','Instrumentalness','Instrumentalness','Mode'],axis=1)

# %%
hot100.head()
# Out:
#              Track         Artist                   Album  Year  Duration  \
# 0          7 rings  Ariana Grande           thank u, next  2019    178626
# 1       Break Free  Ariana Grande  My Everything - Deluxe  2014    214840
# 2  Dangerous Woman  Ariana Grande         Dangerous Woman  2016    235946
# 3   God is a woman  Ariana Grande               Sweetener  2018    197546
# 4         Into You  Ariana Grande         Dangerous Woman  2016    244453
#
#    Time_Signature  Danceability  Energy  Key  Loudness  Speechiness  \
# 0               4         0.780   0.321    1   -10.747       0.3720
# 1               4         0.686   0.702    7    -5.325       0.0455
# 2               3         0.664   0.602    4    -5.369       0.0412
# 3               4         0.602   0.658    1    -5.934       0.0558
# 4               4         0.623   0.734    9    -5.948       0.1070
#
#    Acousticness  Liveness    Tempo  Popularity
# 0       0.56200    0.0881  139.961          50
# ...

# %%
#relationship analysis
print(hot100.dtypes)
# Out:
# Track              object
# Artist             object
# Album              object
# Year                int64
# Duration            int64
# Time_Signature      int64
# Danceability      float64
# Energy            float64
# Key                 int64
# Loudness          float64
# Speechiness       float64
# Acousticness      float64
# Liveness          float64
# Tempo             float64
# Popularity          int64
# dtype: object

# %%
hot100.value_counts()
# Out:
# Track                         Artist          Album                        Year  Duration  Time_Signature  Danceability  Energy  Key  Loudness  Speechiness  Acousticness  Liveness  Tempo    Popularity
# 1 step forward, 3 steps back  Olivia Rodrigo  SOUR                         2021  163586    4               0.473         0.203   2    -12.627   0.1020       0.94100       0.126     168.884  77            1
# Scuse Me                      Lizzo           Coconut Oil                  2019  204392    4               0.803         0.833   0    -4.500    0.0859       0.25900       0.152     129.993  40            1
# SOLD OUT                      HARDY           SOLD OUT                     2020  202912    4               0.504         0.891   9    -4.784    0.0492       0.00527       0.341     144.990  34            1
# ...

# %%
correlation = hot100.select_dtypes(include=[np.float64]).corr()

# %%
sns.heatmap(correlation,xticklabels=correlation.columns,yticklabels=correlation.columns,annot=True)
# Out:
# <Axes: >

# %%
#to visualize relationships between multiple variables in a dataset
sns.pairplot(hot100)

# %%
hot100_subset = hot100.head(30)
sns.relplot(x='Year',y='Artist',hue='Danceability', data=hot100_subset)

# %%
#hostogram
sns.displot (hot100['Duration'])

# %%
sns. boxplot(x=hot100 ['Duration'])
# Out:
# <Axes: xlabel='Duration'>
