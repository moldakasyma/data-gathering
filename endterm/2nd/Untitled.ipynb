# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
data=pd.read_csv("/Users/aja/Desktop/uni/datagath/endterm/2nd/accident_prediction.csv")

# %%
data
# Out:
#     Weather   Road_Type Time_of_Day  Traffic_Density  Speed_Limit  \
# 0     Rainy   City Road     Morning              1.0        100.0
# 1     Clear  Rural Road       Night              NaN        120.0
# 2     Rainy     Highway     Evening              1.0         60.0
# 3     Clear   City Road   Afternoon              2.0         60.0
# 4     Rainy     Highway     Morning              1.0        195.0
# ..      ...         ...         ...              ...          ...
# 835   Clear     Highway       Night              2.0         30.0
# 836   Rainy  Rural Road     Evening              2.0         60.0
# 837   Foggy     Highway     Evening              NaN         30.0
# 838   Foggy     Highway   Afternoon              2.0         60.0
# 839   Clear     Highway   Afternoon              1.0         60.0
#
#      Number_of_Vehicles  Driver_Alcohol Accident_Severity      Road_Condition  \
# 0                   5.0             0.0               NaN                 Wet
# ...

# %%
data.isnull().sum()
# Out:
# Weather                 42
# Road_Type               42
# Time_of_Day             42
# Traffic_Density         42
# Speed_Limit             42
# Number_of_Vehicles      42
# Driver_Alcohol          42
# Accident_Severity       42
# Road_Condition          42
# Vehicle_Type            42
# Driver_Age              42
# Driver_Experience       42
# Road_Light_Condition    42
# Accident                42
# dtype: int64

# %%
cleaned=data.dropna()
cleaned
# Out:
#     Weather   Road_Type Time_of_Day  Traffic_Density  Speed_Limit  \
# 2     Rainy     Highway     Evening              1.0         60.0
# 3     Clear   City Road   Afternoon              2.0         60.0
# 4     Rainy     Highway     Morning              1.0        195.0
# 6     Foggy     Highway   Afternoon              0.0         60.0
# 7     Rainy   City Road   Afternoon              0.0         60.0
# ..      ...         ...         ...              ...          ...
# 830   Clear     Highway     Morning              1.0        100.0
# 835   Clear     Highway       Night              2.0         30.0
# 836   Rainy  Rural Road     Evening              2.0         60.0
# 838   Foggy     Highway   Afternoon              2.0         60.0
# 839   Clear     Highway   Afternoon              1.0         60.0
#
#      Number_of_Vehicles  Driver_Alcohol Accident_Severity      Road_Condition  \
# 2                   4.0             0.0               Low                 Icy
# ...

# %%
cleaned.duplicated().sum()
# Out:
# 12

# %%
cleaned=cleaned.drop_duplicates()
cleaned
# Out:
#     Weather   Road_Type Time_of_Day  Traffic_Density  Speed_Limit  \
# 2     Rainy     Highway     Evening              1.0         60.0
# 3     Clear   City Road   Afternoon              2.0         60.0
# 4     Rainy     Highway     Morning              1.0        195.0
# 6     Foggy     Highway   Afternoon              0.0         60.0
# 7     Rainy   City Road   Afternoon              0.0         60.0
# ..      ...         ...         ...              ...          ...
# 830   Clear     Highway     Morning              1.0        100.0
# 835   Clear     Highway       Night              2.0         30.0
# 836   Rainy  Rural Road     Evening              2.0         60.0
# 838   Foggy     Highway   Afternoon              2.0         60.0
# 839   Clear     Highway   Afternoon              1.0         60.0
#
#      Number_of_Vehicles  Driver_Alcohol Accident_Severity      Road_Condition  \
# 2                   4.0             0.0               Low                 Icy
# ...

# %%
min_age=cleaned['Driver_Age'].min()
print(min_age)
# Out:
# 18.0

# %%
max_age=cleaned['Driver_Age'].max()
print(max_age)
# Out:
# 69.0

# %%
mean_driverExperice=cleaned['Driver_Experience'].mean()
print(mean_driverExperice)
# Out:
# 39.07124681933842

# %%
min_experience=cleaned['Driver_Experience'].min()
print(min_experience)
# Out:
# 9.0

# %%
max_experience=cleaned['Driver_Experience'].max()
print(max_experience)
# Out:
# 69.0

# %%
top=cleaned.head(15)
top.plot(kind='bar', x='Weather', y='Traffic_Density', title='Traffic_Density during a day')
plt.show()

# %%
counts = cleaned['Road_Condition'].value_counts()
counts.plot(kind='bar')
plt.title("road conditions")
plt.xlabel("cleaned['Road_Condition']")
plt.ylabel("Counts")
plt.show()

# %%
top=cleaned.head(15)
top.plot(kind='line', x='Accident_Severity', y='Number_of_Vehicles', title='Accident_Severity')
plt.show()

# %%
top=cleaned.head(15)
top.plot(kind='bar', x='Vehicle_Type', y='Driver_Age', title='Traffic_Density during a day')
plt.show()

# %%
alcohol=cleaned[cleaned['Driver_Alcohol']>1]
alcohol
# Out:
# Empty DataFrame
# Columns: [Weather, Road_Type, Time_of_Day, Traffic_Density, Speed_Limit, Number_of_Vehicles, Driver_Alcohol, Accident_Severity, Road_Condition, Vehicle_Type, Driver_Age, Driver_Experience, Road_Light_Condition, Accident]
# Index: []

# %%
speedy=cleaned[cleaned['Speed_Limit']>120]
speedy
# Out:
#     Weather      Road_Type Time_of_Day  Traffic_Density  Speed_Limit  \
# 4     Rainy        Highway     Morning              1.0        195.0
# 103   Rainy      City Road   Afternoon              1.0        178.0
# 164   Clear      City Road   Afternoon              0.0        213.0
# 206  Stormy      City Road     Evening              0.0        190.0
# 213   Rainy        Highway     Evening              1.0        196.0
# 228   Foggy      City Road       Night              0.0        188.0
# 242  Stormy        Highway     Evening              1.0        195.0
# 355  Stormy      City Road     Evening              1.0        189.0
# 458   Foggy  Mountain Road     Morning              2.0        193.0
# 604   Rainy      City Road     Evening              1.0        213.0
# 667   Clear      City Road     Morning              2.0        198.0
# 670   Clear      City Road     Morning              1.0        192.0
# 714   Rainy  Mountain Road     Evening              0.0        212.0
#
# ...

# %%
top=cleaned.head(15)
top.plot(kind='line', x='Time_of_Day', y='Driver_Age', title='day')
plt.show()
