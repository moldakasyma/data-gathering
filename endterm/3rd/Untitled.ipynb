# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
data=pd.read_csv("/Users/aja/Desktop/uni/datagath/endterm/3rd/netflix_titles.csv")

# %%
data
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
data.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
cleaned=data.dropna()
cleaned
# Out:
#      show_id     type                          title             director  \
# 7         s8    Movie                        Sankofa         Haile Gerima
# 8         s9  TV Show  The Great British Baking Show      Andy Devonshire
# 9        s10    Movie                   The Starling       Theodore Melfi
# 12       s13    Movie                   Je Suis Karl  Christian Schwochow
# 24       s25    Movie                          Jeans           S. Shankar
# ...      ...      ...                            ...                  ...
# 8801   s8802    Movie                        Zinzana      Majid Al Ansari
# 8802   s8803    Movie                         Zodiac        David Fincher
# 8804   s8805    Movie                     Zombieland      Ruben Fleischer
# 8805   s8806    Movie                           Zoom         Peter Hewitt
# 8806   s8807    Movie                         Zubaan          Mozez Singh
#
#                                                    cast  \
# ...

# %%
cleaned.duplicated().sum()
# Out:
# 0

# %%
dur_min=cleaned['duration'].min()
print(dur_min)
# Out:
# 1 Season

# %%
dur_max=cleaned['duration'].max()
print(dur_max)
# Out:
# 99 min

# %%
release_min=cleaned['release_year'].min()
print(release_min)
# Out:
# 1942

# %%
release_max=cleaned['release_year'].max()
print(release_max)
# Out:
# 2021

# %%
data_us=cleaned[cleaned['country']>'United State']
data_us
# Out:
#      show_id   type                 title         director  \
# 7         s8  Movie               Sankofa     Haile Gerima
# 9        s10  Movie          The Starling   Theodore Melfi
# 27       s28  Movie             Grown Ups     Dennis Dugan
# 28       s29  Movie            Dark Skies    Scott Stewart
# 29       s30  Movie              Paranoia   Robert Luketic
# ...      ...    ...                   ...              ...
# 8791   s8792  Movie           Young Adult    Jason Reitman
# 8793   s8794  Movie  Yours, Mine and Ours     Raja Gosnell
# 8802   s8803  Movie                Zodiac    David Fincher
# 8804   s8805  Movie            Zombieland  Ruben Fleischer
# 8805   s8806  Movie                  Zoom     Peter Hewitt
#
#                                                    cast  \
# 7     Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 9     Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# 27    Adam Sandler, Kevin James, Chris Rock, David S...
# ...

# %%
counts = cleaned['type'].value_counts()
counts.plot(kind='bar')
plt.title("type counts")
plt.xlabel("cleaned['type']")
plt.ylabel("Counts")
plt.show()

# %%
movie_type=cleaned[cleaned['listed_in']>'Horror']
movie_type
# Out:
#      show_id   type             title  \
# 28       s29  Movie        Dark Skies
# 29       s30  Movie          Paranoia
# 90       s91  Movie    Paradise Hills
# 122     s123  Movie        In the Cut
# 150     s151  Movie       In Too Deep
# ...      ...    ...               ...
# 8760   s8761  Movie  Would You Rather
# 8765   s8766  Movie                XX
# 8777   s8778  Movie         Yes or No
# 8778   s8779  Movie       Yes or No 2
# 8779   s8780  Movie     Yes or No 2.5
#
#                                                director  \
# 28                                        Scott Stewart
# 29                                       Robert Luketic
# 90                                     Alice Waddington
# 122                                        Jane Campion
# 150                                       Michael Rymer
# ...                                                 ...
# 8760                                     David Guy Levy
# ...

# %%
top=movie_type.head(15)
top.plot(kind='line', x='listed_in', y='release_year', title='horror')
plt.show()

# %%
direct=cleaned[cleaned['director']=='Saratswadee Wongsomphet']
direct
# Out:
#      show_id   type        title                 director  \
# 8777   s8778  Movie    Yes or No  Saratswadee Wongsomphet
# 8778   s8779  Movie  Yes or No 2  Saratswadee Wongsomphet
#
#                                                    cast   country  \
# 8777  Sushar Manaying, Supanart Jittaleela, Arisara ...  Thailand
# 8778  Supanart Jittaleela, Sushar Manaying, Nisa Boo...  Thailand
#
#             date_added  release_year rating duration  \
# 8777  December 6, 2018          2010  TV-PG  111 min
# 8778  November 8, 2018          2012  TV-PG  112 min
#
#                                               listed_in  \
# 8777  International Movies, LGBTQ Movies, Romantic M...
# 8778  International Movies, LGBTQ Movies, Romantic M...
#
#                                             description
# 8777  Traditional girl Pie is initially uncomfortabl...
# 8778  No longer university girls, Kim and Pie face n...

# %%
release_year=cleaned[cleaned['release_year']<2000]
release_year
# Out:
#      show_id   type                                title          director  \
# 7         s8  Movie                              Sankofa      Haile Gerima
# 24       s25  Movie                                Jeans        S. Shankar
# 41       s42  Movie                                 Jaws  Steven Spielberg
# 42       s43  Movie                               Jaws 2    Jeannot Szwarc
# 43       s44  Movie                               Jaws 3         Joe Alves
# ...      ...    ...                                  ...               ...
# 8742   s8743  Movie                       Wild Wild West  Barry Sonnenfeld
# 8745   s8746  Movie  Willy Wonka & the Chocolate Factory        Mel Stuart
# 8748   s8749  Movie                 Winter of Our Dreams       John Duigan
# 8764   s8765  Movie                           Wyatt Earp   Lawrence Kasdan
# 8792   s8793  Movie                          Young Tiger            Mu Chu
#
#                                                    cast  \
# ...

# %%
top=release_year.head(15)
top.plot(kind='line', x='duration', y='release_year', title='horror')
plt.show()

# %%
top=release_year.head(15)
top.plot(kind='line', x='rating', y='release_year', title='horror')
plt.show()
