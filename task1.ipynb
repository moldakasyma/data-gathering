# %% [markdown]
# <a href="https://colab.research.google.com/github/moldakasyma/data-gathering/blob/main/task1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
#1
arr=np.array([[5,7,3],[-1,7,2],[0,3,2]])
print(np.linalg.matrix_rank(arr))
# Out:
# 3

# %%
#2
arr=np.array([[5,7,3],[-1,7,2],[0,3,2]])
print(np.linalg.inv(arr))
# Out:
# [[ 0.17777778 -0.11111111 -0.15555556]
#  [ 0.04444444  0.22222222 -0.28888889]
#  [-0.06666667 -0.33333333  0.93333333]]

# %%
#3
arr=np.array([[5,7,3,2]])
arr2=arr.reshape(2,2)
print(arr2)
# Out:
# [[5 7]
#  [3 2]]

# %%
#4
arr=np.random.rand(3,3)
print(np.linalg.det(arr))
# Out:
# 0.011445358925719237

# %%
#5
arr=np.array([[4,8,1],[3,3,3],[-4,9,1]])
print(np.linalg.matrix_power(arr,2))
# Out:
# [[36 65 29]
#  [ 9 60 15]
#  [ 7  4 24]]

# %%
#6
eq=np.poly1d([2,1,3])
sol=eq.deriv()
print(sol)
# Out:
#
# 4 x + 1

# %%
#6
eq=np.poly1d([1,4,5])
sol=eq.integ()
print(sol(2))
# Out:
# 20.666666666666664

# %%
#7
arr=np.array([[2,7,8],[5,5,5],[9,0,1]])
print(arr.max())
print(arr.min())
# Out:
# 9
# 0

# %%
#8
arr=np.random.rand(3,3)
print(arr.max()-arr.min())
# Out:
# 0.7347611806453922

# %%
#9
arr=np.array([5,6,1,3,8,0,3,2,4])
arr.sort()
print(np.median(arr))
# Out:
# 3.0

# %%
#10
arr=np.array([5,6,1,3,8,0,3,2,4])
print(np.average(arr))
# Out:
# 3.5555555555555554

# %%
#11.standard deviation
arr=np.array([5,5,8,1,0,1,5,2,10,843,65,32])
print(np.std(arr))
# Out:
# 230.32566014715388

# %%
#12
import matplotlib.pyplot as plt
x=np.array([-5,4,6])
y=np.array([6, 8, 9])
plt.plot(x,y)
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.show()

# %%
#13
x = np.linspace(0, np.pi, 1000)
f_x = np.sin(x)
dx = x[1] - x[0]
integral = np.cumsum(f_x) * dx

print( integral[-1])
# Out:
# 1.9999983517708484

# %%
#14
arr=np.array([5,6,1,3,8,0,3,2,4])
arr.sort()
print(np.median(arr))
# Out:
# 3.0

# %%
#15
arr=np.array([5,6,1,3,8,0,3,2,4])
print(np.std(arr))
# Out:
# 2.3622546250521443
